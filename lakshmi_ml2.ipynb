# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
url=r'https://raw.githubusercontent.com/anantdivanji/LearnDigital-/main/4th%20Sem/data.txt'

# %%
data=pd.read_csv(url,sep='|')
data.head()
# Out:
#    Unnamed: 0   Column 1    Column 2    Column 3    Column 4    Column 5   \
# 0         NaN  ----------  ----------  ----------  ----------  ----------
# 1         NaN   1           A           3.14        10          Apple
# 2         NaN   2           B                       20
# 3         NaN   3           C           2.718                   Banana
# 4         NaN               D           1.414       30          Orange
#
#     Column 6   Unnamed: 7
# 0  ----------         NaN
# 1   True              NaN
# 2   False             NaN
# 3   True              NaN
# 4                     NaN

# %%
data=data.drop(columns=['Unnamed: 0','Unnamed: 7'])

# %%
data
# Out:
#      Column 1    Column 2    Column 3    Column 4     Column 5    Column 6
# 0   ----------  ----------  ----------  ----------   ----------  ----------
# 1    1           A           3.14        10           Apple       True
# 2    2           B                       20                       False
# 3    3           C           2.718                    Banana      True
# 4                D           1.414       30           Orange
# 5    5           E                                                False
# 6    6           F           3.0         40           Pear        True
# 7    7                       2.0                                  False
# 8    8           H           1.0         50           Grape       True
# 9    9           I                       60
# 10   10          J           0.5         70           Pineapple   False
# 11   11          K                                                True
# 12   12          L           4.0         80           Coconut
# ...

# %%
data=data.drop(0)

# %%
data[' Column 6 ']
# Out:
# 1      True
# 2      False
# 3      True
# 4
# 5      False
# 6      True
# 7      False
# 8      True
# 9
# 10     False
# 11     True
# 12
# 13     True
# 14     False
# 15     True
# 16     False
# 17     True
# 18     False
# 19     True
# 20     False
# Name:  Column 6 , dtype: object

# %%
X=data.drop(columns=[' Column 6 ',' Column 5 ',' Column 2 '])
X
# Out:
#      Column 1    Column 3    Column 4
# 1    1           3.14        10
# 2    2                       20
# 3    3           2.718
# 4                1.414       30
# 5    5
# 6    6           3.0         40
# 7    7           2.0
# 8    8           1.0         50
# 9    9                       60
# 10   10          0.5         70
# 11   11
# 12   12          4.0         80
# 13   13          5.0
# 14   14                      90
# 15   15          6.0
# 16   16          7.0         100
# 17   17                      110
# 18   18          8.0         120
# 19   19
# 20   20          9.0         130

# %%
y=pd.get_dummies(data[' Column 6 '],dtype='int',drop_first=True)#.drop(columns='False')
y=y.drop(columns=' False    ')
y
# Out:
#      True
# 1            1
# 2            0
# 3            1
# 4            0
# 5            0
# 6            1
# 7            0
# 8            1
# 9            0
# 10           0
# 11           1
# 12           0
# 13           1
# 14           0
# 15           1
# 16           0
# 17           1
# 18           0
# 19           1
# 20           0

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
X_train
# Out:
#      Column 1    Column 3    Column 4
# 4                1.414       30
# 3    3           2.718
# 8    8           1.0         50
# 9    9                       60
# 13   13          5.0
# 12   12          4.0         80
# 2    2                       20
# 1    1           3.14        10
# 14   14                      90
# 20   20          9.0         130
# 15   15          6.0
# 18   18          8.0         120
# 10   10          0.5         70
# 16   16          7.0         100
# 7    7           2.0
# 6    6           3.0         40

# %%
X_test
# Out:
#      Column 1    Column 3    Column 4
# 17   17                      110
# 19   19
# 5    5
# 11   11

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()
lr
# Out:
# LogisticRegression()

# %%
lr.fit(X,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9116\1436335423.py in ?()
# ----> 1 lr.fit(X,y)
#
# ~\anaconda3\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1147                 skip_parameter_validation=(
#    1148                     prefer_skip_nested_validation or global_skip_validation
#    1149                 )
#    1150             ):
# -> 1151                 return fit_method(estimator, *args, **kwargs)
#
# ~\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py in ?(self, X, y, sample_weight)
#    1203             _dtype = np.float64
#    1204         else:
#    1205             _dtype = [np.float64, np.float32]
#    1206
# -> 1207         X, y = self._validate_data(
#    1208             X,
#    1209             y,
#    1210             accept_sparse="csr",
#
# ...

# %% [markdown]
# # To apply machine learning, we need to make sure that the data will not have-
#
# ### 1.missing values
# ### 2.string values

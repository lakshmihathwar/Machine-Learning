# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
url=r'https://raw.githubusercontent.com/anantdivanji/LearnDigital-/main/4th%20Sem/Social_Network_Ads.csv'

# %%
data=pd.read_csv(url)
data.head()
# Out:
#    Age  EstimatedSalary  Purchased
# 0   19            19000          0
# 1   35            20000          0
# 2   26            43000          0
# 3   27            57000          0
# 4   19            76000          0

# %%
data.isnull().sum()
# Out:
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
X=data.drop(columns='Purchased')
X
# Out:
#      Age  EstimatedSalary
# 0     19            19000
# 1     35            20000
# 2     26            43000
# 3     27            57000
# 4     19            76000
# ..   ...              ...
# 395   46            41000
# 396   51            23000
# 397   50            20000
# 398   36            33000
# 399   49            36000
#
# [400 rows x 2 columns]

# %%
y=data['Purchased']
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 395    1
# 396    1
# 397    1
# 398    0
# 399    1
# Name: Purchased, Length: 400, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=1)

# %%
from sklearn.svm import SVR
regressor=SVR(kernel='rbf')
regressor.fit(X,y)
# Out:
# SVR()

# %%
y_pred=regressor.predict(X_test)
y_pred
# Out:
# array([ 1.33264652e-01,  3.42751445e-03,  9.90593717e-01,  1.04277572e+00,
#         9.90589650e-01, -1.03504495e-03,  1.28150390e-01,  2.92078401e-01,
#         8.77910356e-02,  1.02774028e+00,  2.42243031e-02,  3.17912453e-02,
#         2.42250287e-02,  1.08824313e+00,  1.47442157e-01,  1.08485032e+00,
#         1.65443287e-01,  1.36501124e-02,  2.46570120e-01,  6.32245158e-01,
#         5.00798915e-02,  2.68960865e-01,  1.04798052e+00,  1.00027346e-01,
#         1.26253909e-01,  6.68844992e-02,  7.68216572e-02,  4.04120850e-02,
#         1.32099086e-01,  9.20465717e-01,  1.05197117e-01,  6.08058730e-02,
#         2.24978573e-01,  4.04178533e-02,  1.84369944e-01,  1.14406002e-01,
#         8.77858209e-02,  2.24987784e-01,  1.00033598e-01,  1.23081681e-01,
#         9.91102675e-01,  6.05247174e-01,  9.39550988e-01, -2.05423761e-04,
#         6.27942586e-03,  9.90591689e-01,  1.30390150e-01,  9.00404310e-01,
#         9.94349372e-02,  1.22258604e-01,  1.36478632e-02,  3.95918437e-02,
#         1.14414306e-01,  1.30984525e-01,  3.17934143e-02,  1.22759796e-03,
#         1.05212350e-01,  4.56083533e-02,  4.43175646e-01,  1.08683568e+00,
#         2.92064337e-01,  1.47421707e-01,  8.79424184e-01,  5.80258003e-02,
#         5.50932883e-01,  9.91100722e-01,  1.30374893e-01,  1.21920195e-02,
#         1.08484678e+00,  5.80280362e-02,  4.69824281e-01,  9.45499220e-02,
#         9.00400294e-01,  1.77003674e-02,  4.56008782e-02,  7.87460853e-01,
#         5.17695752e-02,  7.41533128e-02,  2.46571424e-01,  6.26363288e-03])

# %%
from sklearn.metrics import mean_squared_error
rms = mean_squared_error(y_test, y_pred, squared=False)

# %%
rms
# Out:
# 0.4964649054573784
